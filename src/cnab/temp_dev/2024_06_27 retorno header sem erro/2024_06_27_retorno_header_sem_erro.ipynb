# %% [markdown]
# ## BACK -  Ler retorno com 2 HeaderArquivo sem dar erro

# %% [markdown]
# ### Ha itens faltando no banco
#
# NúmeroSequencialEmpresa esperados: 49-73

# %%
encontrados = [56,58,59,60,61,62,63,64,65,67,68,69,69,70,70,71,71,72,73]
faltantes = [i for i in range(49,73) if i not in encontrados]
print(faltantes)
# Out:
# [49, 50, 51, 52, 53, 54, 55, 57, 66]

# %% [markdown]
# ### Verificar no front local os TransacaoViews dos usuários

# %%
users = [
    {'name': 'AGUINALDO PAIVA RIBEIRO', 'id_operadora': '463422751', 'id': '50'},
    {'name': 'ANDRE LUIS LOPES', 'id_operadora': '463554555', 'id': '56'},
    {'name': 'CARLOS DOS SANTOS SOARES', 'id_operadora': '463516487', 'id': '60'},
    {'name': 'DIMAS CASCIMIRO DE ARAUJO JUNIOR', 'id_operadora': '463553589', 'id': '55'},
    {'name': 'ELIANE VIEIRA DA SILVA', 'id_operadora': '463423161', 'id': '677'},
    {'name': 'FEORAVANTE RODRIGUES SILVA', 'id_operadora': '463565416', 'id': '1288'},
    {'name': 'INES FERNANDES', 'id_operadora': '463413106', 'id': '67'},
    {'name': 'JOAO SALES DE ALBUQUERQUE', 'id_operadora': '463413258', 'id': '59'},
    {'name': 'JOCIMAR GOMES DUARTE', 'id_operadora': '463423222', 'id': '92'},
    {'name': 'JOSE ALIRIO PEREIRA DELFINO', 'id_operadora': '463572898', 'id': '834'},
    {'name': 'JOSE DIAS XIMENES', 'id_operadora': '463494930', 'id': '232'},
    {'name': 'JOSE MARTINS CORREIA', 'id_operadora': '463553996', 'id': '98'},
    {'name': 'LUCIANE PEREIRA LIMA LOUREIRO', 'id_operadora': '463453401', 'id': '51'},
    {'name': 'LUIZ CARLOS FURTADO DE MELO', 'id_operadora': '463423091', 'id': '62'},
    {'name': 'MARCIA DUARTE SEIXAS', 'id_operadora': '463453085', 'id': '66'},
    {'name': 'MARIA DA GUIA BARROS DA COSTA', 'id_operadora': '463416372', 'id': '47'},
    {'name': 'MARIO FELIX SEIXAS', 'id_operadora': '463453182', 'id': '63'},
    {'name': 'MARIO LUIS ROMAO NUNES', 'id_operadora': '463556092', 'id': '99'},
    {'name': 'RENATO MAXIQUEIRA', 'id_operadora': '463452921', 'id': '109'},
    {'name': 'RICARDO HENRIQUE DA SILVA FERNANDES', 'id_operadora': '463513752', 'id': '58'},
    {'name': 'ROSEMAR FURTADO GONZALEZ', 'id_operadora': '463573350', 'id': '79'},
    {'name': 'ROSEVAL PEREIRA DE SOUZA', 'id_operadora': '463554591', 'id': '269'},
    {'name': 'ROZEMERI VIEIRA DA SILVA', 'id_operadora': '463423170', 'id': '405'},
    {'name': 'SILVIA REIS MACIQUEIRA', 'id_operadora': '463415449', 'id': '105'},
    {'name': 'YURI DELLATORE MACIQUEIRA', 'id_operadora': '463575620', 'id': '81'},
]
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Rapha\anaconda3\envs\general\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\Rapha\anaconda3\envs\general\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
import requests

# def auth():
#     url = 'http://localhost/api/v1/auth/admin/email/login'
#     resp = requests.post(url, data="email=admin@example.,om&password=secret").json()
    
#     return resp

# auth_json = auth()
# print(auth_json)
headers_list = {
 "Accept": "*/*",
 "User-Agent": "Python (jupyter)",
 "Authorization": "bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6MSwicm9sZSI6eyJpZCI6MSwibmFtZSI6IkFkbWluIn0sImlhdCI6MTcxOTU5ODA3NiwiZXhwIjoxNzE5Njg0NDc2fQ.S9IEHakpUsC8K1JjH9eChX7Dpdkbt_EPJIA1iI9dIK0",
 "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6MSwicm9sZSI6eyJpZCI6MSwibmFtZSI6IkFkbWluIn0sImlhdCI6MTcxOTU5ODA3NiwiZXhwIjoxNzE5Njg0NDc2fQ.S9IEHakpUsC8K1JjH9eChX7Dpdkbt_EPJIA1iI9dIK0" 
}

# %%
import requests


def get_month(user_id: str):
    url = f'https://api.cct.mobilidade.rio/api/v1/bank-statements/me?userId={user_id}&timeInterval=lastMonth'
    resp = requests.get(url, headers=headers_list).json()
    return resp

def get_week(user_id:str):
    url = f'https://api.cct.mobilidade.rio/api/v1/ticket-revenues/me/grouped?userId={user_id}&endDate=2024-06-21'
    resp = requests.get(url, headers=headers_list).json()
    return resp

# %%
months = {u['name']: get_month(u['id']) for u in users}

# %%
weeks = {u['name']: get_week(u['id']) for u in users}

# %%
# months_with_transactions = {k:months[k] for k in months if months[k]['ticketCount']}
months_with_transactions = {}
payment_weeks = {}
for k,month in dict.items(months):
    data = [i for i in month['data'] if i['amount']]
    if data:
        month['data'] = data
        months_with_transactions.update({k:month})
        payment_weeks.update({k: [d['date'] for d in data]})

# display(len(months))
# display(months_with_transactions)
# display(payment_weeks)

# %%
months_with_transactions
# Out:
# {'AGUINALDO PAIVA RIBEIRO': {'amountSum': 4.3,
#   'paidSum': 4.13,
#   'todaySum': 0,
#   'count': 4,
#   'ticketCount': 1,
#   'data': [{'id': 2,
#     'amount': 4.3,
#     'paidAmount': 4.13,
#     'cpfCnpj': '36980439715',
#     'date': '2024-06-14',
#     'effectivePaymentDate': '2024-06-14',
#     'permitCode': '463422751',
#     'status': 'Pago',
#     'errors': [],
#     'ticketCount': 1}]},
#  'ANDRE LUIS LOPES': {'amountSum': 8.6,
#   'paidSum': 4.13,
#   'todaySum': 0,
#   'count': 4,
#   'ticketCount': 2,
#   'data': [{'id': 4,
#     'amount': 4.3,
#     'paidAmount': 4.13,
#     'cpfCnpj': '07713033785',
#     'date': '2024-06-28',
#     'effectivePaymentDate': None,
#     'permitCode': '463554555',
#     'status': 'A pagar',
#     'errors': [],
#     'ticketCount': 1},
#    {'id': 2,
#     'amount': 4.3,
#     'paidAmount': 4.13,
#     'cpfCnpj': '07713033785',
#     'date': '2024-06-14',
#     'effectivePaymentDate': '2024-06-14',
#     'permitCode': '463554555',
# ...

# %%
# weeks21 = [w for w in weeks_list if [d for d in w['']]]
display(weeks)
# Out:
# {'AGUINALDO PAIVA RIBEIRO': {'count': 0,
#   'date': '',
#   'transportTypeCounts': {},
#   'directionIdCounts': {},
#   'paymentMediaTypeCounts': {},
#   'transactionTypeCounts': {},
#   'transportIntegrationTypeCounts': {},
#   'stopIdCounts': {},
#   'stopLatCounts': {},
#   'stopLonCounts': {},
#   'transactionValueSum': 0,
#   'paidValueSum': 0,
#   'aux_epochWeek': 0,
#   'aux_nthWeeks': [],
#   'aux_groupDateTime': '',
#   'isPago': False,
#   'errors': []},
#  'ANDRE LUIS LOPES': {'count': 0,
#   'date': '',
#   'transportTypeCounts': {},
#   'directionIdCounts': {},
#   'paymentMediaTypeCounts': {},
#   'transactionTypeCounts': {},
#   'transportIntegrationTypeCounts': {},
#   'stopIdCounts': {},
#   'stopLatCounts': {},
#   'stopLonCounts': {},
#   'transactionValueSum': 0,
#   'paidValueSum': 0,
#   'aux_epochWeek': 0,
#   'aux_nthWeeks': [],
#   'aux_groupDateTime': '',
#   'isPago': False,
#   'errors': []},
#  'CARLOS DOS SANTOS SOARES': {'count': 0,
#   'date': '',
# ...
